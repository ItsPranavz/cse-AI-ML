# %% [markdown]
# # AIML Lab Assignment 1
# > **Objective** : Data exploration
#
# > **Name** : Pranav Sharma
#
# > **SID** : 22103018

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the data from csv
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Showing top 5 entries only
df.iloc[0:5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Showing specific column only
df["Glucose"]
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
# Renaming a column of the dataframe
df.rename(columns={"BloodPressure" : "B.P."}, inplace=True)
df
# Out:
#      Pregnancies  Glucose  B.P.  SkinThickness  Insulin   BMI  \
# 0              6      148    72             35        0  33.6
# 1              1       85    66             29        0  26.6
# 2              8      183    64              0        0  23.3
# 3              1       89    66             23       94  28.1
# 4              0      137    40             35      168  43.1
# ..           ...      ...   ...            ...      ...   ...
# 763           10      101    76             48      180  32.9
# 764            2      122    70             27        0  36.8
# 765            5      121    72             23      112  26.2
# 766            1      126    60              0        0  30.1
# 767            1       93    70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
# Sorting dataframe by column
df.sort_values(by=["Age"])
# Out:
#      Pregnancies  Glucose  B.P.  SkinThickness  Insulin   BMI  \
# 255            1      113    64             35        0  33.6
# 60             2       84     0              0        0   0.0
# 102            0      125    96              0        0  22.5
# 182            1        0    74             20       23  27.7
# 623            0       94    70             27      115  43.5
# ..           ...      ...   ...            ...      ...   ...
# 123            5      132    80              0        0  26.8
# 684            5      136    82              0        0   0.0
# 666            4      145    82             18        0  32.5
# 453            2      119     0              0        0  19.6
# 459            9      134    74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# 60                      0.304   21        0
# 102                     0.262   21        0
# ...

# %%
# Showing column as a series
df.iloc[:,7]
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
# Minimum, maximum and count
df.groupby('Age')['Glucose'].agg(['count', 'min', 'max'])
# Out:
#      count  min  max
# Age
# 21      63    0  177
# 22      72    0  199
# 23      38   68  179
# 24      46   77  193
# 25      48   68  193
# 26      33   71  181
# 27      32   73  166
# 28      35   80  198
# 29      29   86  196
# 30      21   88  170
# 31      24   85  197
# 32      16   81  183
# 33      17   75  173
# 34      14   83  191
# 35      10   77  180
# 36      16   44  187
# 37      19    0  189
# 38      16   72  181
# 39      12   74  197
# 40      13   96  168
# 41      22    0  196
# 42      18   65  156
# 43      13   95  188
# 44       8   92  158
# 45      15  102  183
# 46      13   61  155
# 47       6   68  163
# 48       5   88  120
# 49       5  125  184
# 50       8   99  164
# 51       8  125  181
# 52       8   97  176
# 53       5  105  197
# 54       6  109  171
# 55       4  103  195
# 56       3   90  111
# 57       5   95  196
# 58       7   91  176
# 59       3  137  194
# 60       5  109  181
# 61       2  142  146
# 62       4  105  197
# ...

# %%
df.plot.bar(x = 'Age', y = 'Glucose', fontsize='9')
# Out:
# <Axes: xlabel='Age'>
