# %% [markdown]
# # AIML Lab Assignment 3
# > **Objective** : Search algorithms
#
# > **Name** : Pranav Sharma
#
# > **SID** : 22103018

# %%
# Define the graph
graph = {'A': set(['B', 'C', 'D']),
         'B': set(['A', 'D']),
         'C': set(['A', 'F', 'E']),
         'D': set(['B']),
         'E': set(['B', 'F']),
         'F': set(['C', 'E', 'A'])}
# Display the graph
graph
# Out:
# {'A': {'B', 'C', 'D'},
#  'B': {'A', 'D'},
#  'C': {'A', 'E', 'F'},
#  'D': {'B'},
#  'E': {'B', 'F'},
#  'F': {'A', 'C', 'E'}}

# %%
# Show graph using values()
graph.values()
# Out:
# dict_values([{'D', 'B', 'C'}, {'A', 'D'}, {'F', 'A', 'E'}, {'B'}, {'F', 'B'}, {'A', 'E', 'C'}])

# %%
# Depth First Search

def dfs(graph, start):
  visited, stack = set(), [start]
  while stack:
      vertex = stack.pop()
      print(vertex)
      if vertex not in visited:
          visited.add(vertex)
          stack.extend(graph[vertex] - visited)
  return visited

# %%
# Breadth First Search

def bfs(graph, start):
    visited, queue = set(), [start]
    while queue:
        vertex = queue.pop(0)
        print(vertex)
        if vertex not in visited:
            visited.add(vertex)
            queue.extend(graph[vertex] - visited)
    return visited

# %%
dfs(graph, 'E')
# Out:
# E
# B
# D
# A
# C
# F
# F
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %%
bfs(graph, 'C')
# Out:
# C
# A
# F
# E
# D
# B
# E
# B
# B
# {'A', 'B', 'C', 'D', 'E', 'F'}
